# %%
import os
os.environ['HADOOP_CONF_DIR'] = '/etc/hadoop/conf'
os.environ['YARN_CONF_DIR'] = '/etc/hadoop/conf'

import findspark
findspark.init()
findspark.find()
# Out:
# '/opt/spark'

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder \
                    .master("local") \
                    .appName("Learning DataFrames") \
                    .getOrCreate()
# Out:
# /opt/spark/conf/spark-env.sh: line 31: hadoop: command not found
# 26/08/19 12:09:53 WARN Utils: Your hostname, fv4nf4tmrgckt81afvbi resolves to a loopback address: 127.0.1.1; using 10.130.0.8 instead (on interface eth0)
# 26/08/19 12:09:53 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/08/19 12:09:55 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
events = spark.read.json("/user/master/data/events/date=2022-05-31")

# %%
events.show(10)
# Out:
# +--------------------+------------+
# |               event|  event_type|
# +--------------------+------------+
# |{null, null, 2022...|subscription|
# |{null, null, 2022...|subscription|
# |{null, null, 2022...|subscription|
# |{null, null, 2022...|subscription|
# |{null, null, 2022...|subscription|
# |{null, null, 2022...|subscription|
# |{null, null, 2022...|subscription|
# |{null, null, 2022...|subscription|
# |{null, null, 2022...|subscription|
# |{null, null, 2022...|subscription|
# +--------------------+------------+
# only showing top 10 rows

# %% [markdown]
# ## Task 1

# %%
! /opt/hadoop/bin/hdfs dfs -mkdir -p /user/s18314377/data/events

# %%
events.write.option("header", True) \
  .mode("append") \
  .parquet("/user/s18314377/data/events")

# %%
! /opt/hadoop/bin/hdfs dfs -ls /user/s18314377/data/events
# Out:
# Found 2 items
# -rw-r--r--   1 s18314377 hadoop          0 2026-08-19 12:17 /user/s18314377/data/events/_SUCCESS
# -rw-r--r--   1 s18314377 hadoop    4236144 2026-08-19 12:17 /user/s18314377/data/events/part-00000-dffc7c1a-4eeb-46fc-970a-9397dee211b4-c000.snappy.parquet

# %%
import pyspark.sql.functions as F
events_ods = spark.read.parquet("/user/s18314377/data/events")

events_ods.withColumn('date', F.to_date('event.datetime')).orderBy(F.desc('event.datetime')).show(10)
# Out:
# +--------------------+------------+----------+
# |               event|  event_type|      date|
# +--------------------+------------+----------+
# |{[19342], 987160,...|     message|2022-05-31|
# |{null, null, 2022...|subscription|2022-05-31|
# |{[26358], 247511,...|     message|2022-05-31|
# |{[79792], 748847,...|     message|2022-05-31|
# |{null, null, 2022...|subscription|2022-05-31|
# |{null, null, 2022...|subscription|2022-05-31|
# |{[151897], 396845...|     message|2022-05-31|
# |{null, null, 2022...|subscription|2022-05-31|
# |{null, null, 2022...|subscription|2022-05-31|
# |{null, null, 2022...|subscription|2022-05-31|
# +--------------------+------------+----------+
# only showing top 10 rows
# [Stage 15:>                                                         (0 + 1) / 1]
