# %%
import os
os.environ['HADOOP_CONF_DIR'] = '/etc/hadoop/conf'
os.environ['YARN_CONF_DIR'] = '/etc/hadoop/conf'

import findspark
findspark.init()
findspark.find()
# Out:
# '/opt/spark'

# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
                    .master("local") \
                    .appName("Checking Spark UI 3") \
                    .getOrCreate()
# Out:
# /opt/spark/conf/spark-env.sh: line 31: hadoop: command not found
# 26/08/18 21:31:19 WARN Utils: Your hostname, fv4im62q1f2ij1439k95 resolves to a loopback address: 127.0.1.1; using 10.130.0.37 instead (on interface eth0)
# 26/08/18 21:31:19 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
events = spark.read.json("/user/master/data/events/date=2022-05-25")
events.select("event.message_from").filter("event_type == 'reaction'").count()
